# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
#Preparing data for Tensorflow and Keras
#label -> Hot Encoding
label = pd.get_dummies (df['label'],prefix='label')
df = pd.concat([df,label],axis=1)
#Drop the old label
df.drop(['label'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and Y
X = df[['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']]
#Convert into an array
X = np.asarray(X)

y = df[['label_setosa','label_versicolor','label_virginica']]
y = np.asarray(y)

# %%
#Splitting the data into train & test
X_train, X_test,y_train, y_test= train_test_split(X, y, test_size = 0.20)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %%
#Batch Normalisation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
#Model without Batch normalisation
model = Sequential ([
    Dense(64, input_shape=(4,), activation = 'relu'),
    Dense(128, activation = 'relu'),
    Dense(128, activation = 'relu'),
    Dense(64, activation = 'relu'),
    Dense(64, activation = 'relu'),
    Dense(3, activation = 'softmax'),
    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 37,763
# Trainable params: 37,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
#Customised Batch Normalization
from tensorflow.keras.initializers import RandomNormal, Constant

# Model with a customized batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(momentum = 0.95,
                      epsilon = 0.005,
                      beta_initializer= RandomNormal(mean= 0.0,stddev=0.05),
                      gamma_initializer = Constant(value=0.9)),
    Dense(3, activation='softmax')
    ])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 64)                320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
#Training and compile
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
             metrics=['accuracy'])

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 0s - loss: 1.5795 - accuracy: 0.3556 - val_loss: 1.0867 - val_accuracy: 0.7333
# Epoch 2/200
# 3/3 - 0s - loss: 0.3912 - accuracy: 0.9222 - val_loss: 1.0556 - val_accuracy: 0.3667
# Epoch 3/200
# 3/3 - 0s - loss: 0.1841 - accuracy: 0.9778 - val_loss: 1.0286 - val_accuracy: 0.3667
# Epoch 4/200
# 3/3 - 0s - loss: 0.1899 - accuracy: 0.9444 - val_loss: 1.0112 - val_accuracy: 0.3667
# Epoch 5/200
# 3/3 - 0s - loss: 0.1229 - accuracy: 0.9778 - val_loss: 0.9990 - val_accuracy: 0.3667
# Epoch 6/200
# 3/3 - 0s - loss: 0.1888 - accuracy: 0.9556 - val_loss: 0.9899 - val_accuracy: 0.3667
# Epoch 7/200
# 3/3 - 0s - loss: 0.1281 - accuracy: 0.9778 - val_loss: 0.9851 - val_accuracy: 0.3667
# Epoch 8/200
# 3/3 - 0s - loss: 0.0967 - accuracy: 0.9778 - val_loss: 0.9819 - val_accuracy: 0.3667
# Epoch 9/200
# 3/3 - 0s - loss: 0.0557 - accuracy: 0.9889 - val_loss: 0.9788 - val_accuracy: 0.3667
# Epoch 10/200
# 3/3 - 0s - loss: 0.0583 - accuracy: 0.9889 - val_loss: 0.9749 - val_accuracy: 0.3667
# Epoch 11/200
# 3/3 - 0s - loss: 0.0755 - accuracy: 0.9889 - val_loss: 0.9730 - val_accuracy: 0.4000
# Epoch 12/200
# 3/3 - 0s - loss: 0.0638 - accuracy: 0.9889 - val_loss: 0.9668 - val_accuracy: 0.4000
# Epoch 13/200
# 3/3 - 0s - loss: 0.0482 - accuracy: 0.9889 - val_loss: 0.9624 - val_accuracy: 0.4000
# Epoch 14/200
# 3/3 - 0s - loss: 0.0756 - accuracy: 0.9778 - val_loss: 0.9607 - val_accuracy: 0.4333
# Epoch 15/200
# 3/3 - 0s - loss: 0.0495 - accuracy: 0.9889 - val_loss: 0.9574 - val_accuracy: 0.5000
# Epoch 16/200
# 3/3 - 0s - loss: 0.0463 - accuracy: 0.9778 - val_loss: 0.9572 - val_accuracy: 0.5667
# Epoch 17/200
# 3/3 - 0s - loss: 0.0547 - accuracy: 0.9778 - val_loss: 0.9555 - val_accuracy: 0.6000
# Epoch 18/200
# 3/3 - 0s - loss: 0.0437 - accuracy: 0.9889 - val_loss: 0.9625 - val_accuracy: 0.6333
# Epoch 19/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9889 - val_loss: 0.9667 - val_accuracy: 0.6333
# Epoch 20/200
# 3/3 - 0s - loss: 0.0561 - accuracy: 0.9778 - val_loss: 0.9805 - val_accuracy: 0.6333
# Epoch 21/200
# 3/3 - 0s - loss: 0.0633 - accuracy: 0.9889 - val_loss: 0.9880 - val_accuracy: 0.6333
# Epoch 22/200
# 3/3 - 0s - loss: 0.0558 - accuracy: 0.9778 - val_loss: 0.9735 - val_accuracy: 0.6333
# Epoch 23/200
# 3/3 - 0s - loss: 0.0443 - accuracy: 0.9778 - val_loss: 0.9746 - val_accuracy: 0.6333
# Epoch 24/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.9686 - val_accuracy: 0.6333
# Epoch 25/200
# 3/3 - 0s - loss: 0.0903 - accuracy: 0.9778 - val_loss: 0.9692 - val_accuracy: 0.6333
# Epoch 26/200
# 3/3 - 0s - loss: 0.2787 - accuracy: 0.9333 - val_loss: 0.9812 - val_accuracy: 0.6333
# Epoch 27/200
# 3/3 - 0s - loss: 0.0256 - accuracy: 1.0000 - val_loss: 1.0041 - val_accuracy: 0.6000
# Epoch 28/200
# 3/3 - 0s - loss: 0.0468 - accuracy: 0.9778 - val_loss: 1.0252 - val_accuracy: 0.6000
# Epoch 29/200
# 3/3 - 0s - loss: 0.0651 - accuracy: 0.9778 - val_loss: 1.0307 - val_accuracy: 0.6000
# Epoch 30/200
# 3/3 - 0s - loss: 0.1523 - accuracy: 0.9667 - val_loss: 1.0226 - val_accuracy: 0.6333
# Epoch 31/200
# 3/3 - 0s - loss: 0.1071 - accuracy: 0.9778 - val_loss: 1.0095 - val_accuracy: 0.6333
# Epoch 32/200
# 3/3 - 0s - loss: 0.0559 - accuracy: 0.9889 - val_loss: 1.0071 - val_accuracy: 0.6333
# Epoch 33/200
# 3/3 - 0s - loss: 0.1515 - accuracy: 0.9556 - val_loss: 1.0212 - val_accuracy: 0.6333
# Epoch 34/200
# 3/3 - 0s - loss: 0.0343 - accuracy: 0.9889 - val_loss: 1.0648 - val_accuracy: 0.6000
# Epoch 35/200
# 3/3 - 0s - loss: 0.0785 - accuracy: 0.9889 - val_loss: 1.0901 - val_accuracy: 0.6000
# Epoch 36/200
# 3/3 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 1.1010 - val_accuracy: 0.5667
# Epoch 37/200
# 3/3 - 0s - loss: 0.0280 - accuracy: 1.0000 - val_loss: 1.1122 - val_accuracy: 0.5667
# Epoch 38/200
# 3/3 - 0s - loss: 0.0846 - accuracy: 0.9667 - val_loss: 1.1011 - val_accuracy: 0.6333
# Epoch 39/200
# 3/3 - 0s - loss: 0.0549 - accuracy: 0.9778 - val_loss: 1.0943 - val_accuracy: 0.6333
# Epoch 40/200
# 3/3 - 0s - loss: 0.0769 - accuracy: 0.9778 - val_loss: 1.0825 - val_accuracy: 0.6333
# Epoch 41/200
# 3/3 - 0s - loss: 0.0572 - accuracy: 0.9889 - val_loss: 1.0965 - val_accuracy: 0.6000
# Epoch 42/200
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9889 - val_loss: 1.0829 - val_accuracy: 0.6000
# Epoch 43/200
# 3/3 - 0s - loss: 0.0704 - accuracy: 0.9778 - val_loss: 1.0575 - val_accuracy: 0.6000
# Epoch 44/200
# 3/3 - 0s - loss: 0.0338 - accuracy: 1.0000 - val_loss: 1.0480 - val_accuracy: 0.6000
# Epoch 45/200
# 3/3 - 0s - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.0233 - val_accuracy: 0.6000
# Epoch 46/200
# 3/3 - 0s - loss: 0.0441 - accuracy: 0.9889 - val_loss: 0.9906 - val_accuracy: 0.6000
# Epoch 47/200
# 3/3 - 0s - loss: 0.0671 - accuracy: 0.9889 - val_loss: 0.9644 - val_accuracy: 0.6000
# Epoch 48/200
# 3/3 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.9051 - val_accuracy: 0.6333
# Epoch 49/200
# 3/3 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.8689 - val_accuracy: 0.6333
# Epoch 50/200
# 3/3 - 0s - loss: 0.0769 - accuracy: 0.9778 - val_loss: 0.8415 - val_accuracy: 0.6333
# Epoch 51/200
# 3/3 - 0s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.6333
# Epoch 52/200
# 3/3 - 0s - loss: 0.1019 - accuracy: 0.9778 - val_loss: 0.8048 - val_accuracy: 0.6333
# Epoch 53/200
# 3/3 - 0s - loss: 0.0422 - accuracy: 0.9889 - val_loss: 0.7866 - val_accuracy: 0.6333
# Epoch 54/200
# 3/3 - 0s - loss: 0.0585 - accuracy: 0.9778 - val_loss: 0.7604 - val_accuracy: 0.6333
# Epoch 55/200
# 3/3 - 0s - loss: 0.0834 - accuracy: 0.9778 - val_loss: 0.7431 - val_accuracy: 0.6333
# Epoch 56/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 0.9889 - val_loss: 0.7291 - val_accuracy: 0.6000
# Epoch 57/200
# 3/3 - 0s - loss: 0.2259 - accuracy: 0.9444 - val_loss: 0.7432 - val_accuracy: 0.5667
# Epoch 58/200
# 3/3 - 0s - loss: 0.0990 - accuracy: 0.9556 - val_loss: 0.8088 - val_accuracy: 0.4667
# Epoch 59/200
# 3/3 - 0s - loss: 0.0679 - accuracy: 0.9667 - val_loss: 0.8012 - val_accuracy: 0.5333
# Epoch 60/200
# 3/3 - 0s - loss: 0.1572 - accuracy: 0.9667 - val_loss: 0.7605 - val_accuracy: 0.6000
# Epoch 61/200
# 3/3 - 0s - loss: 0.0396 - accuracy: 0.9889 - val_loss: 0.7542 - val_accuracy: 0.6333
# Epoch 62/200
# 3/3 - 0s - loss: 0.0932 - accuracy: 0.9778 - val_loss: 0.7725 - val_accuracy: 0.6333
# Epoch 63/200
# 3/3 - 0s - loss: 0.0940 - accuracy: 0.9667 - val_loss: 0.7727 - val_accuracy: 0.6333
# Epoch 64/200
# 3/3 - 0s - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.7616 - val_accuracy: 0.6333
# Epoch 65/200
# 3/3 - 0s - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.7598 - val_accuracy: 0.6333
# Epoch 66/200
# 3/3 - 0s - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.7504 - val_accuracy: 0.6000
# Epoch 67/200
# 3/3 - 0s - loss: 0.0568 - accuracy: 0.9778 - val_loss: 0.7054 - val_accuracy: 0.6000
# Epoch 68/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9889 - val_loss: 0.6578 - val_accuracy: 0.6333
# Epoch 69/200
# 3/3 - 0s - loss: 0.0286 - accuracy: 0.9889 - val_loss: 0.6251 - val_accuracy: 0.6667
# Epoch 70/200
# 3/3 - 0s - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.5778 - val_accuracy: 0.7000
# Epoch 71/200
# 3/3 - 0s - loss: 0.0558 - accuracy: 0.9778 - val_loss: 0.5288 - val_accuracy: 0.7000
# Epoch 72/200
# 3/3 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.4892 - val_accuracy: 0.7667
# Epoch 73/200
# 3/3 - 0s - loss: 0.0293 - accuracy: 0.9889 - val_loss: 0.4621 - val_accuracy: 0.8000
# Epoch 74/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.4346 - val_accuracy: 0.8000
# Epoch 75/200
# 3/3 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4241 - val_accuracy: 0.8333
# Epoch 76/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.8333
# Epoch 77/200
# 3/3 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.3782 - val_accuracy: 0.8667
# Epoch 78/200
# 3/3 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.9000
# Epoch 79/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9889 - val_loss: 0.3178 - val_accuracy: 0.9333
# Epoch 80/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.2543 - val_accuracy: 1.0000
# Epoch 81/200
# 3/3 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 1.0000
# Epoch 82/200
# 3/3 - 0s - loss: 0.0298 - accuracy: 0.9889 - val_loss: 0.1932 - val_accuracy: 1.0000
# Epoch 83/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 0.9889 - val_loss: 0.1814 - val_accuracy: 0.9667
# Epoch 84/200
# 3/3 - 0s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9667
# Epoch 85/200
# 3/3 - 0s - loss: 0.0329 - accuracy: 0.9889 - val_loss: 0.1629 - val_accuracy: 0.9667
# Epoch 86/200
# 3/3 - 0s - loss: 0.0297 - accuracy: 0.9889 - val_loss: 0.1560 - val_accuracy: 0.9667
# Epoch 87/200
# 3/3 - 0s - loss: 0.0617 - accuracy: 0.9778 - val_loss: 0.1476 - val_accuracy: 0.9667
# Epoch 88/200
# 3/3 - 0s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9667
# Epoch 89/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 0.9889 - val_loss: 0.1300 - val_accuracy: 0.9667
# Epoch 90/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9667
# Epoch 91/200
# 3/3 - 0s - loss: 0.0262 - accuracy: 0.9889 - val_loss: 0.1442 - val_accuracy: 0.9667
# Epoch 92/200
# 3/3 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9000
# Epoch 93/200
# 3/3 - 0s - loss: 0.0583 - accuracy: 0.9667 - val_loss: 0.2391 - val_accuracy: 0.9000
# Epoch 94/200
# 3/3 - 0s - loss: 0.0501 - accuracy: 0.9667 - val_loss: 0.1025 - val_accuracy: 0.9667
# Epoch 95/200
# 3/3 - 0s - loss: 0.0273 - accuracy: 0.9889 - val_loss: 0.0819 - val_accuracy: 0.9667
# Epoch 96/200
# 3/3 - 0s - loss: 0.0744 - accuracy: 0.9778 - val_loss: 0.0812 - val_accuracy: 0.9667
# Epoch 97/200
# 3/3 - 0s - loss: 0.0460 - accuracy: 0.9778 - val_loss: 0.0903 - val_accuracy: 0.9667
# Epoch 98/200
# 3/3 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9667
# Epoch 99/200
# 3/3 - 0s - loss: 0.0736 - accuracy: 0.9667 - val_loss: 0.1062 - val_accuracy: 0.9667
# Epoch 100/200
# 3/3 - 0s - loss: 0.0467 - accuracy: 0.9778 - val_loss: 0.0955 - val_accuracy: 0.9667
# Epoch 101/200
# 3/3 - 0s - loss: 0.0216 - accuracy: 0.9889 - val_loss: 0.0892 - val_accuracy: 0.9667
# Epoch 102/200
# 3/3 - 0s - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0926 - val_accuracy: 0.9667
# Epoch 103/200
# 3/3 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9667
# Epoch 104/200
# 3/3 - 0s - loss: 0.0215 - accuracy: 0.9889 - val_loss: 0.1346 - val_accuracy: 0.9667
# Epoch 105/200
# 3/3 - 0s - loss: 0.1541 - accuracy: 0.9667 - val_loss: 0.1329 - val_accuracy: 0.9667
# Epoch 106/200
# 3/3 - 0s - loss: 0.0898 - accuracy: 0.9667 - val_loss: 0.1279 - val_accuracy: 0.9667
# Epoch 107/200
# 3/3 - 0s - loss: 0.0320 - accuracy: 0.9889 - val_loss: 0.1348 - val_accuracy: 0.9667
# Epoch 108/200
# 3/3 - 0s - loss: 0.0674 - accuracy: 0.9889 - val_loss: 0.1228 - val_accuracy: 0.9667
# Epoch 109/200
# 3/3 - 0s - loss: 0.0260 - accuracy: 0.9889 - val_loss: 0.1068 - val_accuracy: 0.9667
# Epoch 110/200
# 3/3 - 0s - loss: 0.0380 - accuracy: 0.9889 - val_loss: 0.0818 - val_accuracy: 0.9667
# Epoch 111/200
# 3/3 - 0s - loss: 0.0608 - accuracy: 0.9889 - val_loss: 0.0571 - val_accuracy: 0.9667
# Epoch 112/200
# 3/3 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9667
# Epoch 113/200
# 3/3 - 0s - loss: 0.0379 - accuracy: 0.9889 - val_loss: 0.0569 - val_accuracy: 0.9667
# Epoch 114/200
# 3/3 - 0s - loss: 0.1055 - accuracy: 0.9556 - val_loss: 0.0531 - val_accuracy: 0.9667
# Epoch 115/200
# 3/3 - 0s - loss: 0.0715 - accuracy: 0.9667 - val_loss: 0.0481 - val_accuracy: 0.9667
# Epoch 116/200
# 3/3 - 0s - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.0458 - val_accuracy: 0.9667
# Epoch 117/200
# 3/3 - 0s - loss: 0.0618 - accuracy: 0.9778 - val_loss: 0.0478 - val_accuracy: 0.9667
# Epoch 118/200
# 3/3 - 0s - loss: 0.0408 - accuracy: 0.9889 - val_loss: 0.0566 - val_accuracy: 0.9667
# Epoch 119/200
# 3/3 - 0s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9667
# Epoch 120/200
# 3/3 - 0s - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9667
# Epoch 121/200
# 3/3 - 0s - loss: 0.1786 - accuracy: 0.9444 - val_loss: 0.0742 - val_accuracy: 0.9667
# Epoch 122/200
# 3/3 - 0s - loss: 0.0882 - accuracy: 0.9556 - val_loss: 0.0683 - val_accuracy: 0.9667
# Epoch 123/200
# 3/3 - 0s - loss: 0.1407 - accuracy: 0.9778 - val_loss: 0.0641 - val_accuracy: 0.9667
# Epoch 124/200
# 3/3 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9667
# Epoch 125/200
# 3/3 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9667
# Epoch 126/200
# 3/3 - 0s - loss: 0.0657 - accuracy: 0.9889 - val_loss: 0.0628 - val_accuracy: 0.9667
# Epoch 127/200
# 3/3 - 0s - loss: 0.1863 - accuracy: 0.9444 - val_loss: 0.0588 - val_accuracy: 0.9667
# Epoch 128/200
# 3/3 - 0s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9667
# Epoch 129/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9667
# Epoch 130/200
# 3/3 - 0s - loss: 0.0629 - accuracy: 0.9889 - val_loss: 0.0960 - val_accuracy: 0.9667
# Epoch 131/200
# 3/3 - 0s - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.0921 - val_accuracy: 0.9667
# Epoch 132/200
# 3/3 - 0s - loss: 0.1307 - accuracy: 0.9556 - val_loss: 0.0824 - val_accuracy: 0.9667
# Epoch 133/200
# 3/3 - 0s - loss: 0.0551 - accuracy: 0.9778 - val_loss: 0.1024 - val_accuracy: 0.9667
# Epoch 134/200
# 3/3 - 0s - loss: 0.0720 - accuracy: 0.9889 - val_loss: 0.1160 - val_accuracy: 0.9667
# Epoch 135/200
# 3/3 - 0s - loss: 0.0636 - accuracy: 0.9889 - val_loss: 0.1118 - val_accuracy: 0.9667
# Epoch 136/200
# 3/3 - 0s - loss: 0.0620 - accuracy: 0.9889 - val_loss: 0.0917 - val_accuracy: 0.9667
# Epoch 137/200
# 3/3 - 0s - loss: 0.0519 - accuracy: 0.9778 - val_loss: 0.0804 - val_accuracy: 0.9667
# Epoch 138/200
# 3/3 - 0s - loss: 0.2427 - accuracy: 0.9000 - val_loss: 0.0888 - val_accuracy: 0.9667
# Epoch 139/200
# 3/3 - 0s - loss: 0.0617 - accuracy: 0.9889 - val_loss: 0.0977 - val_accuracy: 0.9667
# Epoch 140/200
# 3/3 - 0s - loss: 0.0503 - accuracy: 0.9889 - val_loss: 0.1144 - val_accuracy: 0.9667
# Epoch 141/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 0.9889 - val_loss: 0.1315 - val_accuracy: 0.9667
# Epoch 142/200
# 3/3 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9667
# Epoch 143/200
# 3/3 - 0s - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9333
# Epoch 144/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.1578 - val_accuracy: 0.9333
# Epoch 145/200
# 3/3 - 0s - loss: 0.0540 - accuracy: 0.9778 - val_loss: 0.1462 - val_accuracy: 0.9333
# Epoch 146/200
# 3/3 - 0s - loss: 0.0597 - accuracy: 0.9889 - val_loss: 0.1256 - val_accuracy: 0.9667
# Epoch 147/200
# 3/3 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9667
# Epoch 148/200
# 3/3 - 0s - loss: 0.0326 - accuracy: 0.9889 - val_loss: 0.1176 - val_accuracy: 0.9667
# Epoch 149/200
# 3/3 - 0s - loss: 0.1081 - accuracy: 0.9667 - val_loss: 0.1086 - val_accuracy: 0.9667
# Epoch 150/200
# 3/3 - 0s - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9667
# Epoch 151/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.1152 - val_accuracy: 0.9667
# Epoch 152/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9667
# Epoch 153/200
# 3/3 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9667
# Epoch 154/200
# 3/3 - 0s - loss: 0.0618 - accuracy: 0.9778 - val_loss: 0.1093 - val_accuracy: 0.9667
# Epoch 155/200
# 3/3 - 0s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9667
# Epoch 156/200
# 3/3 - 0s - loss: 0.0423 - accuracy: 0.9889 - val_loss: 0.1188 - val_accuracy: 0.9667
# Epoch 157/200
# 3/3 - 0s - loss: 0.0311 - accuracy: 0.9889 - val_loss: 0.1170 - val_accuracy: 0.9667
# Epoch 158/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9667
# Epoch 159/200
# 3/3 - 0s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9667
# Epoch 160/200
# 3/3 - 0s - loss: 0.0755 - accuracy: 0.9778 - val_loss: 0.1315 - val_accuracy: 0.9667
# Epoch 161/200
# 3/3 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9667
# Epoch 162/200
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9667
# Epoch 163/200
# 3/3 - 0s - loss: 0.0679 - accuracy: 0.9667 - val_loss: 0.1303 - val_accuracy: 0.9667
# Epoch 164/200
# 3/3 - 0s - loss: 0.0344 - accuracy: 0.9889 - val_loss: 0.1269 - val_accuracy: 0.9667
# Epoch 165/200
# 3/3 - 0s - loss: 0.1067 - accuracy: 0.9556 - val_loss: 0.1227 - val_accuracy: 0.9667
# Epoch 166/200
# 3/3 - 0s - loss: 0.0650 - accuracy: 0.9778 - val_loss: 0.1249 - val_accuracy: 0.9667
# Epoch 167/200
# 3/3 - 0s - loss: 0.0268 - accuracy: 0.9889 - val_loss: 0.1427 - val_accuracy: 0.9667
# Epoch 168/200
# 3/3 - 0s - loss: 0.0813 - accuracy: 0.9778 - val_loss: 0.1752 - val_accuracy: 0.9667
# Epoch 169/200
# 3/3 - 0s - loss: 0.0300 - accuracy: 0.9889 - val_loss: 0.2382 - val_accuracy: 0.9333
# Epoch 170/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 0.9889 - val_loss: 0.2153 - val_accuracy: 0.9667
# Epoch 171/200
# 3/3 - 0s - loss: 0.0583 - accuracy: 0.9667 - val_loss: 0.1678 - val_accuracy: 0.9667
# Epoch 172/200
# 3/3 - 0s - loss: 0.0241 - accuracy: 0.9889 - val_loss: 0.1372 - val_accuracy: 0.9667
# Epoch 173/200
# 3/3 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9333
# Epoch 174/200
# 3/3 - 0s - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.1445 - val_accuracy: 0.9667
# Epoch 175/200
# 3/3 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9667
# Epoch 176/200
# 3/3 - 0s - loss: 0.1106 - accuracy: 0.9556 - val_loss: 0.2701 - val_accuracy: 0.9333
# Epoch 177/200
# 3/3 - 0s - loss: 0.0627 - accuracy: 0.9778 - val_loss: 0.2767 - val_accuracy: 0.9333
# Epoch 178/200
# 3/3 - 0s - loss: 0.1094 - accuracy: 0.9556 - val_loss: 0.1995 - val_accuracy: 0.9667
# Epoch 179/200
# 3/3 - 0s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9667
# Epoch 180/200
# 3/3 - 0s - loss: 0.0962 - accuracy: 0.9667 - val_loss: 0.1556 - val_accuracy: 0.9667
# Epoch 181/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9667
# Epoch 182/200
# 3/3 - 0s - loss: 0.1022 - accuracy: 0.9667 - val_loss: 0.1662 - val_accuracy: 0.9667
# Epoch 183/200
# 3/3 - 0s - loss: 0.0476 - accuracy: 0.9889 - val_loss: 0.1363 - val_accuracy: 0.9667
# Epoch 184/200
# 3/3 - 0s - loss: 0.0392 - accuracy: 0.9889 - val_loss: 0.1068 - val_accuracy: 0.9667
# Epoch 185/200
# 3/3 - 0s - loss: 0.0663 - accuracy: 0.9667 - val_loss: 0.0817 - val_accuracy: 0.9667
# Epoch 186/200
# 3/3 - 0s - loss: 0.0639 - accuracy: 0.9778 - val_loss: 0.0720 - val_accuracy: 0.9667
# Epoch 187/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 0.9889 - val_loss: 0.0847 - val_accuracy: 0.9667
# Epoch 188/200
# 3/3 - 0s - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9667
# Epoch 189/200
# 3/3 - 0s - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.1055 - val_accuracy: 0.9667
# Epoch 190/200
# 3/3 - 0s - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9667
# Epoch 191/200
# 3/3 - 0s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9667
# Epoch 192/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9667
# Epoch 193/200
# 3/3 - 0s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9667
# Epoch 194/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9667
# Epoch 195/200
# 3/3 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9667
# Epoch 196/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9667
# Epoch 197/200
# 3/3 - 0s - loss: 0.0249 - accuracy: 0.9889 - val_loss: 0.0894 - val_accuracy: 0.9667
# Epoch 198/200
# 3/3 - 0s - loss: 0.0277 - accuracy: 0.9889 - val_loss: 0.0883 - val_accuracy: 0.9667
# Epoch 199/200
# 3/3 - 0s - loss: 0.0676 - accuracy: 0.9778 - val_loss: 0.0778 - val_accuracy: 0.9667
# Epoch 200/200
# 3/3 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9333

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# [0.01085755880922079, 1.0]
